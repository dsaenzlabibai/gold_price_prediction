# %% [markdown]
# # Gold Price Prediction
# ## Implementation with Tensorflow on AWS

# %%
import time

# Web-scrapping Yahoo Finance data
import yfinance as yf

# Data ETL
import re
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 12)
plt.style.use('seaborn-darkgrid')
import seaborn as sns
sns.set_style('darkgrid')

# Training & Testing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %% [markdown]
# ## Collect Data
#
# We scrap the value for gold from Yahoo Finace:

# %%
stocks = [
    {"stock_name": "Standard and Poor's (S&P) 500 index", "stock_ticker": "^GSPC", "feature": True},
    {"stock_name": "Dow Jones Industrial Average", "stock_ticker": "^DJI", "feature": True},
    {"stock_name": "Crude Oil", "stock_ticker": "CL=F", "feature": True},
    {"stock_name": "Gold Miners ETF", "stock_ticker": "GLD", "feature": False}
]

# Lets have a look at the Gold Miners ETF information
gld = yf.Ticker(stocks[-1]["stock_ticker"])
# gld.info

# %%
# Now lets collect the data from the companies
data = yf.download(
    " ".join([obs['stock_ticker'] for obs in stocks]), 
    start="2000-01-01",
    end="2022-06-01",
    group_by='ticker')

data.columns = data.columns.map('_'.join)
data.columns = [c.lower() for c in data.columns]
data.columns = [c.replace("^", "") for c in data.columns]
data.columns = [c.replace("=", "") for c in data.columns]
data.columns = [c.replace(" ", "_") for c in data.columns]
data.reset_index()
print("Total number of observations is:", len(data))
data
# Out:
# [*********************100%***********************]  4 of 4 completed
# Total number of observations is: 5644
#               gld_open    gld_high     gld_low   gld_close  gld_adj_close  \
# Date
# 1999-12-31         NaN         NaN         NaN         NaN            NaN
# 2000-01-03         NaN         NaN         NaN         NaN            NaN
# 2000-01-04         NaN         NaN         NaN         NaN            NaN
# 2000-01-05         NaN         NaN         NaN         NaN            NaN
# 2000-01-06         NaN         NaN         NaN         NaN            NaN
# ...                ...         ...         ...         ...            ...
# 2022-05-24  173.470001  174.410004  173.350006  174.130005     174.130005
# 2022-05-25  172.789993  173.160004  171.729996  173.080002     173.080002
# 2022-05-26  172.130005  172.929993  171.759995  172.759995     172.759995
# 2022-05-27  173.490005  173.520004  172.639999  172.850006     172.850006
# 2022-05-31  172.710007  173.070007  171.080002  171.139999     171.139999
#
#             gld_volume    clf_open    clf_high     clf_low   clf_close  ...  \
# Date                                                                    ...
# 1999-12-31         NaN         NaN         NaN         NaN         NaN  ...
# 2000-01-03         NaN         NaN         NaN         NaN         NaN  ...
# 2000-01-04         NaN         NaN         NaN         NaN         NaN  ...
# 2000-01-05         NaN         NaN         NaN         NaN         NaN  ...
# 2000-01-06         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2022-05-24   6794000.0  110.410004  111.430000  108.610001  109.769997  ...
# 2022-05-25   4595900.0  110.389999  111.680000  109.230003  110.330002  ...
# 2022-05-26   6467000.0  110.690002  114.830002  110.269997  114.089996  ...
# 2022-05-27   3847900.0  114.199997  115.300003  112.849998  115.070000  ...
# 2022-05-31   6244000.0  114.959999  119.980003  114.150002  114.669998  ...
#
#                  dji_low     dji_close  dji_adj_close   dji_volume  \
# Date
# 1999-12-31  11442.820312  11497.120117   11497.120117   43620000.0
# 2000-01-03  11305.690430  11357.509766   11357.509766  169750000.0
# 2000-01-04  10986.450195  10997.929688   10997.929688  178420000.0
# 2000-01-05  10938.669922  11122.650391   11122.650391  203190000.0
# 2000-01-06  11098.450195  11253.259766   11253.259766  176550000.0
# ...                  ...           ...            ...          ...
# 2022-05-24  31365.589844  31928.619141   31928.619141  382950000.0
# 2022-05-25  31754.330078  32120.279297   32120.279297  343460000.0
# 2022-05-26  32248.169922  32637.189453   32637.189453  351220000.0
# 2022-05-27  32682.009766  33212.960938   33212.960938  328770000.0
# 2022-05-31  32752.339844  32990.121094   32990.121094  533560000.0
#
#               gspc_open    gspc_high     gspc_low   gspc_close  \
# Date
# 1999-12-31  1464.469971  1472.420044  1458.189941  1469.250000
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951
# ...                 ...          ...          ...          ...
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088
# 2022-05-27  4077.429932  4158.490234  4077.429932  4158.240234
# 2022-05-31  4151.089844  4168.339844  4104.879883  4132.149902
#
#             gspc_adj_close   gspc_volume
# Date
# 1999-12-31     1469.250000  3.740500e+08
# 2000-01-03     1455.219971  9.318000e+08
# 2000-01-04     1399.420044  1.009000e+09
# 2000-01-05     1402.109985  1.085500e+09
# 2000-01-06     1403.449951  1.092300e+09
# ...                    ...           ...
# 2022-05-24     3941.479980  3.901640e+09
# 2022-05-25     3978.729980  4.322190e+09
# 2022-05-26     4057.840088  3.961940e+09
# 2022-05-27     4158.240234  3.560560e+09
# 2022-05-31     4132.149902  5.192220e+09
#
# [5644 rows x 24 columns]

# %% [markdown]
# ## ETL Data

# %%
def log_return(series, periods = 1) :
    return np.log(series).diff(periods = periods)

# %%
X_features = [col for col in data.columns if re.search('^gspc', col) or re.search('^clf', col) or re.search('^dji', col)]
df = data[X_features]
# df['target'] = log_return(data['gld_close']).shift(-1)
df['target'] = data['gld_close'].shift(-1)
df.dropna(inplace=True)

# Check what features are highly correlated between them
cor_map = df.corr()
ax = sns.heatmap(cor_map, xticklabels=True, yticklabels=True, linewidths=.5)
# Out:
# /home/dsaenzpe/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/dsaenzpe/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
X_features = ['clf_adj_close', 'clf_volume', 'dji_adj_close', 'dji_volume', 'gspc_adj_close', 'gspc_volume', 'target']
df = df[X_features]

X_train, X_val = train_test_split(df, test_size=0.15, shuffle = False)

# Normalize data using training information
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

X_val, X_test = train_test_split(X_val, test_size=0.33, shuffle = False)

# %% [markdown]
# ## Training

# %%
def conv_sequence_input(data, target_column=-1, window_size=64):
    X = []
    y = []

    for i in range(0 , data.shape[0] - window_size, 1):
        temp2 = []
        for t in range(window_size):
            temp2.append(data[i + t, 0])
        X.append(np.array(temp2).reshape(window_size, 1))
        y.append(data[i + window_size, target_column])
    X = np.array(X)
    y = np.array(y).reshape(-1, 1)

    if X.shape[1] > 1:
        for j in range(1, data.shape[1]):
            temp = []
            for i in range(0 , data.shape[0] - window_size, 1):
                temp2 = []
                for t in range(window_size):
                    temp2.append(data[i + t, j])
                temp.append(np.array(temp2).reshape(window_size, 1))
            X = np.concatenate((X, temp), axis=-1)

    return X, y

# %%
window_size = 64

X_train, y_train = conv_sequence_input(X_train, target_column=-1, window_size=window_size)
X_val, y_val = conv_sequence_input(X_val, target_column=-1, window_size=window_size)
X_test, y_test = conv_sequence_input(X_test, target_column=-1, window_size=window_size)

# %%
X_train = np.expand_dims(X_train, axis=1)
X_val = np.expand_dims(X_val, axis=1)
X_test = np.expand_dims(X_test, axis=1)

print("Training data shape:", X_train.shape)
print("Training data shape:", X_val.shape)
print("Training data shape:", X_test.shape)
# Out:
# Training data shape: (3678, 1, 64, 7)
# Training data shape: (378, 1, 64, 7)
# Training data shape: (155, 1, 64, 7)

# %%
def build_model(optimizer='adam', activation='relu', conv_filters=64, kernel_size=3, window_size=64, n_time_features=4, seq_neurons=120, dropout_rate=0.5, dense_neurons=16) :
    inputs = keras.layers.Input(shape = (None, window_size, n_time_features,))
    x = keras.layers.TimeDistributed(keras.layers.Conv1D(conv_filters, kernel_size=kernel_size, activation=activation))(inputs)
    x = keras.layers.TimeDistributed(keras.layers.MaxPooling1D(2))(x)
    x = keras.layers.TimeDistributed(keras.layers.Conv1D(conv_filters * 2, kernel_size=kernel_size, activation=activation))(x)
    x = keras.layers.TimeDistributed(keras.layers.MaxPooling1D(2))(x)
    x = keras.layers.TimeDistributed(keras.layers.Conv1D(conv_filters * 3, kernel_size=kernel_size, activation=activation))(x)
    x = keras.layers.TimeDistributed(keras.layers.MaxPooling1D(2))(x)
    x = keras.layers.TimeDistributed(keras.layers.Flatten())(x)

    x = keras.layers.Bidirectional(keras.layers.LSTM(seq_neurons, return_sequences=True))(x)
    x = keras.layers.Dropout(dropout_rate)(x)
    x = keras.layers.Bidirectional(keras.layers.LSTM(seq_neurons, return_sequences=False))(x)
    x = keras.layers.Dropout(dropout_rate)(x)

    x = keras.layers.Dense(dense_neurons)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation(activation)(x)
    outputs = keras.layers.Dense(1, activation = 'linear')(x)
    
    model = keras.models.Model(inputs = inputs,
                               outputs = outputs)

    model.compile(
        optimizer = optimizer,
        loss = keras.losses.MeanAbsoluteError(),
        metrics = [keras.metrics.RootMeanSquaredError(name = 'rmse'), keras.metrics.MeanAbsoluteError(name='mae')]
    )
    return model

# %%
model = build_model(seq_neurons = 2 * window_size, dense_neurons = 512, window_size = window_size, n_time_features=X_train.shape[-1])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 64, 7)]     0
# _________________________________________________________________
# time_distributed (TimeDistri (None, None, 62, 64)      1408
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 31, 64)      0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, None, 29, 128)     24704
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, None, 14, 128)     0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, None, 12, 192)     73920
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, None, 6, 192)      0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, None, 1152)        0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 256)         1311744
# _________________________________________________________________
# dropout (Dropout)            (None, None, 256)         0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,940,161
# Trainable params: 1,939,137
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
cb = [
    keras.callbacks.EarlyStopping(patience = 10,
                                  mode = 'min',
                                  monitor = 'val_rmse',
                                  restore_best_weights = True),
    keras.callbacks.ModelCheckpoint(filepath="/l/users/dsaenz/GoldPricePrediction/Models/weights.hdf5",
                                    monitor='val_loss',
                                    verbose=1,
                                    save_best_only=True,
                                    save_weights_only=True,
                                    mode='min',),
    keras.callbacks.TensorBoard(log_dir="/l/users/dsaenz/GoldPricePrediction/logs",
                                histogram_freq=1),
    keras.callbacks.ReduceLROnPlateau(patience = 5,
                                      mode = 'min',
                                      monitor = 'val_rmse',
                                      factor = .3,
                                      min_lr = 1e-5)
]

model = KerasRegressor(
    build_model, epochs = 100, callbacks = cb, batch_size = 128, verbose = 1, seq_neurons = 2 * window_size,
    optimizer = 'adam', dense_neurons = 512, window_size = window_size, n_time_features=X_train.shape[-1]
)

# %%
history = model.fit(X_train, y_train,
          validation_data = (X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# <ipython-input-13-b249a7210e92> in <module>
#       1 history = model.fit(X_train, y_train,
# ----> 2           validation_data = (X_val, y_val))
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1073             verbose=verbose,
#    1074             epochs=epochs,
# -> 1075             steps=data_handler.inferred_steps)
#    1076
#    1077       self.stop_training = False
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in __init__(self, callbacks, add_history, add_progbar, model, **params)
#     229
#     230     if model:
# --> 231       self.set_model(model)
#     232     if params:
#     233       self.set_params(params)
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in set_model(self, model)
#     284       model.history = self._history
#     285     for callback in self.callbacks:
# --> 286       callback.set_model(model)
#     287
#     288   def _call_batch_hook(self, mode, hook, batch, logs=None):
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in set_model(self, model)
#    2120     self._should_write_train_graph = False
#    2121     if self.write_graph:
# -> 2122       self._write_keras_model_summary()
#    2123       self._should_write_train_graph = True
#    2124     if self.embeddings_freq:
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in _write_keras_model_summary(self)
#    2159   def _write_keras_model_summary(self):
#    2160     """Writes Keras graph network summary to TensorBoard."""
# -> 2161     with self._train_writer.as_default():
#    2162       with summary_ops_v2.always_record_summaries():
#    2163         summary_writable = (
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in _train_writer(self)
#    2129     if 'train' not in self._writers:
#    2130       self._writers['train'] = summary_ops_v2.create_file_writer_v2(
# -> 2131           self._train_dir)
#    2132     return self._writers['train']
#    2133
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/ops/summary_ops_v2.py in create_file_writer_v2(logdir, max_queue, flush_millis, filename_suffix, name)
#     514           name=name,
#     515           v2=True,
# --> 516           metadata={"logdir": logdir})
#     517
#     518
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/ops/summary_ops_v2.py in __init__(self, shared_name, init_op_fn, name, v2, metadata)
#     283     # TODO(nickfelt): cache other constructed ops in graph mode
#     284     self._init_op_fn = init_op_fn
# --> 285     self._init_op = init_op_fn(self._resource)
#     286     self._v2 = v2
#     287     self._metadata = {} if metadata is None else metadata
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/ops/gen_summary_ops.py in create_summary_file_writer(writer, logdir, max_queue, flush_millis, filename_suffix, name)
#     144       return _result
#     145     except _core._NotOkStatusException as e:
# --> 146       _ops.raise_from_not_ok_status(e, name)
#     147     except _core._FallbackException:
#     148       pass
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# ~/anaconda3/envs/gold_prediction/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# PermissionDeniedError: /l; Permission denied [Op:CreateSummaryFileWriter]

# %%
# %tensorboard --logdir /l/users/dsaenz/GoldPricePrediction/logs
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
history = pd.DataFrame(history.history)
_ = history.loc[:, ['rmse', 'val_rmse']].plot.line()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d5a2d6dc3d48> in <module>
# ----> 1 history = pd.DataFrame(history.history)
#       2 _ = history.loc[:, ['rmse', 'val_rmse']].plot.line()
#
# NameError: name 'history' is not defined

# %%
y_hat = np.array(
    model.predict(X_test)
).reshape(-1, 1)
print('RMSE :', np.sqrt(np.mean(np.square(y_test - y_hat))))
print('Correlation :', np.corrcoef(y_test, y_hat)[1, 0])
plt.plot(y_test, label = 'True Values')
plt.plot(y_hat, label = 'Predicted Values')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 1s 7ms/step
# RMSE : 0.051345105198491496
# Correlation : nan
# /home/dsaenz/conda_envs/gold_prediction/lib/python3.6/site-packages/numpy/lib/function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/dsaenz/conda_envs/gold_prediction/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/dsaenz/conda_envs/gold_prediction/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %% [markdown]
# ### Save model

# %%
ts = int(time.time())
file_path = "/l/users/dsaenz/GoldPricePrediction/Models" + f"/gold_price_predictor/{ts}/"
model.model.save(filepath=file_path, save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_172_layer_call_fn, lstm_cell_172_layer_call_and_return_conditional_losses, lstm_cell_173_layer_call_fn, lstm_cell_173_layer_call_and_return_conditional_losses, lstm_cell_175_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /l/users/dsaenz/GoldPricePrediction/Models/gold_price_predictor/1654691205/assets
# INFO:tensorflow:Assets written to: /l/users/dsaenz/GoldPricePrediction/Models/gold_price_predictor/1654691205/assets
